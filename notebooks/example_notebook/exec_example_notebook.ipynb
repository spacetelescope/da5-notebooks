# %% [markdown]
# # This is a notebook

# %%
12
# Out:
# 12

# %%
import numpy as np
np.random.randn(12345)  # that's amazing, I've got the same combination on my luggage!
# Out:
# array([-2.22830974, -1.28526821, -0.63178184, ...,  1.52390618,
#         0.06894051,  0.61816512])
